# %%
#importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#reading the dataset
df = pd.read_csv(r"heart_v2.csv")
df.head()
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   70    1  130         322              1
# 1   67    0  115         564              0
# 2   57    1  124         261              1
# 3   64    1  128         263              0
# 4   74    0  120         269              0

# %%
#creating the  X and y variables
X = df.drop('heart disease',axis=1)

y = df['heart disease']

# %%
X.head()
# Out:
#    age  sex   BP  cholestrol
# 0   70    1  130         322
# 1   67    0  115         564
# 2   57    1  124         261
# 3   64    1  128         263
# 4   74    0  120         269

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: heart disease, Length: 270, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,test_size=0.3,random_state=100)

# %%
X_train
# Out:
#      age  sex   BP  cholestrol
# 55    41    0  105         198
# 22    43    1  115         303
# 200   68    1  118         277
# 11    53    1  142         226
# 15    71    0  112         149
# ..   ...  ...  ...         ...
# 226   62    0  130         263
# 66    51    1  140         261
# 53    63    0  140         195
# 79    56    1  120         236
# 8     60    1  140         293
#
# [189 rows x 4 columns]

# %%
X_test
# Out:
#      age  sex   BP  cholestrol
# 69    47    1  108         243
# 196   58    0  100         248
# 235   62    0  160         164
# 59    62    1  120         281
# 101   67    1  120         237
# ..   ...  ...  ...         ...
# 201   58    1  125         300
# 97    58    1  100         234
# 48    66    1  160         246
# 160   38    1  120         231
# 133   64    1  120         246
#
# [81 rows x 4 columns]

# %%
X_train.shape,X_test.shape
# Out:
# ((189, 4), (81, 4))

# %% [markdown]
# Fitting the decision tree with default hyperparameters, apart from max_depth which is 3 so that we can plot and read the tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# !pip install six
# Out:
# Requirement already satisfied: six in c:\users\khandal\anaconda3\lib\site-packages (1.15.0)

# %%
#importing the required packages needed for visulaization
from IPython.display import Image
from six import StringIO
from sklearn.tree import export_graphviz
import pydotplus, graphviz

# %%
#plotting the tree with max depth 3
dot_data = StringIO()

export_graphviz(dt, out_file=dot_data, filled=True, rounded=True,
                feature_names=X.columns, 
                class_names=['No Disease', "Disease"])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())

# %% [markdown]
# #### Evaluating model performance

# %%
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
print(accuracy_score(y_train,y_train_pred))
confusion_matrix(y_test_pred,y_test)
# Out:
# 0.7354497354497355
# array([[22, 14],
#        [23, 22]], dtype=int64)

# %%
print(accuracy_score(y_test, y_test_pred))
confusion_matrix(y_test, y_test_pred)
# Out:
# 0.5432098765432098
# array([[22, 23],
#        [14, 22]], dtype=int64)
